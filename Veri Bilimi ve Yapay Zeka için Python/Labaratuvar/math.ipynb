# %%
43 + 60 + 16 + 41
# Out:
# 160

# %%
5 * 5
# Out:
# 25

# %%
total_min = 43 + 42 + 57
total_hours = total_min / 60 
print(total_hours)
# Out:
# 2.3666666666666667

# %%
y = (3 + 2) * 2
y
# Out:
# 10
