# %%
"The BodyGuard"
# Out:
# 'The BodyGuard'

# %%
'@#2_#]&*^%$'
# Out:
# '@#2_#]&*^%$'

# %%
print("hello!")
# Out:
# hello!

# %%
name = "The BodyGuard"
name
# Out:
# 'The BodyGuard'

# %%
print(name[0])
# Out:
# T

# %%
print(name[10])
# Out:
# a

# %%
print(name[-1])
#Son element
# Out:
# d

# %%
print(name[-13])
#İlk element
# Out:
# T

# %%
name[0:4]
# Out:
# 'The '

# %%
name[8:12]
# Out:
# 'Guar'

# %%
statement = name + " is the best album"
statement
# Out:
# 'The BodyGuard is the best album'

# %%
3 * "The BodyGuard"
# Out:
# 'The BodyGuardThe BodyGuardThe BodyGuard'

# %%
print(" The BodyGuard\n is the best album" )
# \n alt satıra inmesini sağlar
# Out:
#  The BodyGuard
#  is the best album

# %%
print(" The BodyGuard \t is the best album" )
# \t slash atmasını sağlar
# Out:
#  The BodyGuard 	 is the best album

# %%
print(r" The BodyGuard \ is the best album" )
"""
Bu, ham string (raw string) anlamına gelir.

Ham string'de:

\ karakteri özel anlamını kaybeder

Python onu normal bir karakter olarak yazar

Yani \n, \t gibi kaçış karakterleri çalışmaz.
"""
# Out:
#  The BodyGuard \ is the best album
# "\nBu, ham string (raw string) anlamına gelir.\n\nHam string'de:\n\n\\ karakteri özel anlamını kaybeder\n\nPython onu normal bir karakter olarak yazar\n\nYani \n, \t gibi kaçış karakterleri çalışmaz.\n"

# %%
a = "Thriller is the sixth studio album"
print("before upper:", a)
b = a.upper()
print("After upper:", b)
# Out:
# before upper: Thriller is the sixth studio album
# After upper: THRILLER IS THE SIXTH STUDIO ALBUM

# %%
a = "The BodyGuard is the best album"
b = a.replace('BodyGuard', 'Janet')
b
# Out:
# 'The Janet is the best album'

# %%
name = "The BodyGuard"
name.find('he')
# Out:
# 1

# %%
name.find('Guard')
# Out:
# 8

# %%
name.find('Jasdfasdasdf')
# Out:
# -1

# %%
name = "The BodyGuard"
split_string = (name.split())
split_string
# Out:
# ['The', 'BodyGuard']
