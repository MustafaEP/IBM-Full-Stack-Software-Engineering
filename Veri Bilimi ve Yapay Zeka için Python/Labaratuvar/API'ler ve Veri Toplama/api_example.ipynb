# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py): started
#   Building wheel for randomuser (setup.py): finished with status 'done'
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5088 sha256=64f5e21ddeac43f0275c28896645c092f16f95fbfa82237d58aef3d5b3872ef6
#   Stored in directory: c:\users\porta\appdata\local\pip\cache\wheels\a8\ce\f1\713605b6f257e4f0efca0fe272df8e2427bd335cf907ab0dff
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6
#   DEPRECATION: Building 'randomuser' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'randomuser'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
from randomuser import RandomUser
import pandas as pd

# %%
r = RandomUser()

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x1ea13471090>,
#  <randomuser.RandomUser at 0x1ea13470cd0>,
#  <randomuser.RandomUser at 0x1ea15afd810>,
#  <randomuser.RandomUser at 0x1ea15afd940>,
#  <randomuser.RandomUser at 0x1ea135aa9f0>,
#  <randomuser.RandomUser at 0x1ea1347b8a0>,
#  <randomuser.RandomUser at 0x1ea15abb020>,
#  <randomuser.RandomUser at 0x1ea15b30a50>,
#  <randomuser.RandomUser at 0x1ea15b30950>,
#  <randomuser.RandomUser at 0x1ea14953e30>]

# %%
name = r.get_full_name()

# %%
for user in some_list:
    print(user.get_full_name(), " ", user.get_email())
# Out:
# Samir Oliveira   samir.oliveira@example.com
# Sören Klinke   soren.klinke@example.com
# Eliza Welch   eliza.welch@example.com
# Fred Gilbert   fred.gilbert@example.com
# Johan Lemaire   johan.lemaire@example.com
# Sofie Olsen   sofie.olsen@example.com
# Matas Engelstad   matas.engelstad@example.com
# Isla Valli   isla.valli@example.com
# Noah Cole   noah.cole@example.com
# Elmer Smith   elmer.smith@example.com

# %%
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/25.jpg
# https://randomuser.me/api/portraits/men/30.jpg
# https://randomuser.me/api/portraits/women/43.jpg
# https://randomuser.me/api/portraits/men/27.jpg
# https://randomuser.me/api/portraits/men/60.jpg
# https://randomuser.me/api/portraits/women/37.jpg
# https://randomuser.me/api/portraits/men/15.jpg
# https://randomuser.me/api/portraits/women/12.jpg
# https://randomuser.me/api/portraits/men/48.jpg
# https://randomuser.me/api/portraits/men/28.jpg

# %%
def get_users():
    users= []
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                 Name  Gender              City        State  \
# 0     Junior Neleman    male            Warten    Groningen
# 1       Robin Vestby    male        Steinshamn    Hordaland
# 2      Naja Pedersen  female            Ishoej  Nordjylland
# 3  Angelina Rottmann  female         Viechtach       Berlin
# 4       Rosa Guillot  female             Pully       Zürich
# 5        Janne Volle  female       Beitostølen    Hordaland
# 6  Matusalém da Rosa    male   Itaquaquecetuba   Pernambuco
# 7       Brianna Cruz  female       Grants Pass     Maryland
# 8        آنیتا رضایی  female          قائم‌شهر         فارس
# 9     Russel Barbosa    male  Feira de Santana      Sergipe
#
#                            Email                       DOB  \
# 0     junior.neleman@example.com  1962-10-29T11:04:09.287Z
# 1       robin.vestby@example.com  1948-08-25T12:05:58.122Z
# 2      naja.pedersen@example.com  1985-12-20T02:07:25.861Z
# 3  angelina.rottmann@example.com  1993-03-31T15:00:27.378Z
# 4       rosa.guillot@example.com  1968-03-28T21:29:49.848Z
# 5        janne.volle@example.com  1992-05-10T22:28:42.426Z
# 6   matusalem.darosa@example.com  1958-04-11T12:08:55.034Z
# 7       brianna.cruz@example.com  1967-04-28T01:33:42.779Z
# 8          anyt.rdyy@example.com  1987-09-27T06:09:39.999Z
# 9     russel.barbosa@example.com  1990-06-18T16:25:39.650Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/19.jpg
# 1     https://randomuser.me/api/portraits/men/0.jpg
# 2  https://randomuser.me/api/portraits/women/92.jpg
# 3   https://randomuser.me/api/portraits/women/1.jpg
# 4  https://randomuser.me/api/portraits/women/47.jpg
# 5  https://randomuser.me/api/portraits/women/47.jpg
# 6    https://randomuser.me/api/portraits/men/78.jpg
# 7   https://randomuser.me/api/portraits/women/3.jpg
# 8  https://randomuser.me/api/portraits/women/61.jpg
# 9    https://randomuser.me/api/portraits/men/24.jpg

# %%
df1 = pd.DataFrame(get_users())

# %%
import requests
import json

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")

# %%
results = json.loads(data.text)

# %%
pd.DataFrame(results).head()
# Out:
#          name  id      family         order      genus  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria
# 2      Banana   1    Musaceae  Zingiberales       Musa
# 3      Tomato   5  Solanaceae     Solanales    Solanum
# 4        Pear   4    Rosaceae       Rosales      Pyrus
#
#                                           nutritions
# 0  {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2  {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3  {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4  {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# 11                 Fig   68         Moraceae           Rosales         Ficus
# 12          Gooseberry   69  Grossulariaceae      Saxifragales         Ribes
# 13        Passionfruit   70   Passifloraceae      Malpighiales    Passiflora
# 14                Plum   71         Rosaceae           Rosales        Prunus
# 15              Orange    2         Rutaceae        Sapindales        Citrus
# 16          GreenApple   72         Rosaceae           Rosales         Malus
# 17           Raspberry   23         Rosaceae           Rosales         Rubus
# 18          Watermelon   25    Cucurbitaceae      Cucurbitales     Citrullus
# 19               Lemon   26         Rutaceae        Sapindales        Citrus
# 20               Mango   27    Anacardiaceae        Sapindales     Mangifera
# 21           Blueberry   33         Rosaceae           Rosales      Fragaria
# 22               Apple    6         Rosaceae           Rosales         Malus
# 23               Guava   37        Myrtaceae          Myrtales       Psidium
# 24             Apricot   35         Rosaceae           Rosales        Prunus
# 25               Melon   41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 26           Tangerine   77         Rutaceae        Sapindales        Citrus
# 27            Pitahaya   78        Cactaceae    Caryophyllales     Cactaceae
# 28                Lime   44         Rutaceae        Sapindales        Citrus
# 29         Pomegranate   79       Lythraceae          Myrtales        Punica
# 30         Dragonfruit   80        Cactaceae    Caryophyllales  Selenicereus
# 31               Grape   81         Vitaceae           Vitales         Vitis
# 32               Morus   82         Moraceae           Rosales         Morus
# 33              Feijoa   76        Myrtaceae        Myrtoideae    Sellowiana
# 34             Avocado   84        Lauraceae          Laurales        Persea
# 35           Kiwifruit   85    Actinidiaceae          Ericales     Actinidia
# 36           Cranberry   87        Ericaceae          Ericales     Vaccinium
# 37              Cherry    9         Rosaceae           Rosales        Prunus
# 38               Peach   86         Rosaceae           Rosales        Prunus
# 39           Jackfruit   94         Moraceae           Rosales    Artocarpus
# 40        Horned Melon   95    Cucurbitaceae      Cucurbitales       Cucumis
# 41            Hazelnut   96       Betulaceae           Fagales       Corylus
# 42              Pomelo   98         Rutaceae        Sapindales        Citrus
# 43          Mangosteen   99       Clusiaceae      Malpighiales      Garcinia
# 44             Pumpkin  100    Cucurbitaceae      Cucurbitales     Cucurbita
# 45  Japanese Persimmon  101        Ebenaceae          Ericales     Diospyros
# 46              Papaya   42       Caricaceae       Brassicales        Carica
# 47              Annona  103       Annonaceae           Rosales       Annonas
# 48   Ceylon Gooseberry  104       Salicaceae      Malpighiales      Dovyalis
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 0                    81            0.00             18.00
# 1                    29            0.40              5.40
# 2                    96            0.20             17.20
# 3                    74            0.20              2.60
# 4                    57            0.10             10.00
# 5                   147            5.30              6.75
# 6                    40            0.40              4.50
# 7                    50            0.34              5.74
# 8                    61            0.50              9.00
# 9                    66            0.44             15.00
# 10                   50            0.12              9.85
# 11                   74            0.30             16.00
# 12                   44            0.60              0.00
# 13                   97            0.70             11.20
# 14                   46            0.28              9.92
# 15                   43            0.20              8.20
# 16                   21            0.10              6.40
# 17                   53            0.70              4.40
# 18                   30            0.20              6.00
# 19                   29            0.30              2.50
# 20                   60            0.38             13.70
# 21                   29            0.40              5.40
# 22                   52            0.40             10.30
# 23                   68            1.00              9.00
# 24                   15            0.10              3.20
# 25                   34            0.00              8.00
# 26                   45            0.40              9.10
# 27                   36            0.40              3.00
# 28                   25            0.10              1.70
# 29                   83            1.20             13.70
# 30                   60            1.50              8.00
# 31                   69            0.16             16.00
# 32                   43            0.39              8.10
# 33                   44            0.40              3.00
# 34                  160           14.66              0.66
# 35                   61            0.50              8.90
# 36                   46            0.10              4.00
# 37                   50            0.30              8.00
# 38                   39            0.25              8.40
# 39                   95            0.00             19.10
# 40                   44            1.26              0.50
# 41                  628           61.00              4.30
# 42                   37            0.00              8.50
# 43                   73            0.58             16.11
# 44                   25            0.30              3.30
# 45                   70            0.20             13.00
# 46                   39            0.30              4.40
# 47                   92            0.29              3.40
# 48                   47            0.30              8.10
#
#     nutritions.carbohydrates  nutritions.protein
# 0                      18.00                0.00
# 1                       5.50                0.80
# 2                      22.00                1.00
# 3                       3.90                0.90
# 4                      15.00                0.40
# 5                      27.10                1.50
# 6                       9.00                1.30
# 7                      11.30                0.75
# 8                      15.00                1.10
# 9                      17.00                0.80
# 10                     13.12                0.54
# 11                     19.00                0.80
# 12                     10.00                0.90
# 13                     22.40                2.20
# 14                     11.40                0.70
# 15                      8.30                1.00
# 16                      3.10                0.40
# 17                     12.00                1.20
# 18                      8.00                0.60
# 19                      9.00                1.10
# 20                     15.00                0.82
# 21                      5.50                0.00
# 22                     11.40                0.30
# 23                     14.00                2.60
# 24                      3.90                0.50
# 25                      8.00                0.00
# 26                      8.30                0.00
# 27                      7.00                1.00
# 28                      8.40                0.30
# 29                     18.70                1.70
# 30                      9.00                9.00
# 31                     18.10                0.72
# 32                      9.80                1.44
# 33                      8.00                0.60
# 34                      8.53                2.00
# 35                     14.60                1.14
# 36                     12.20                0.40
# 37                     12.00                1.00
# 38                      9.50                0.90
# 39                     23.20                1.72
# 40                      7.56                1.78
# 41                     17.00               15.00
# 42                      9.67                0.82
# 43                     17.91                0.41
# 44                      4.60                1.10
# 45                     19.00                0.60
# 46                      5.80                0.50
# 47                     19.10                1.50
# 48                      9.60                1.20

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %%
cal_banana = df2.loc[df2["name"] == 'Banana']
cal_banana.iloc[0]['nutritions.calories']
# Out:
# np.int64(96)

# %%
url_joke = 'https://official-joke-api.appspot.com/jokes/ten'

# %%
data_joke = requests.get(url_joke)

# %%
results_joke = json.loads(data_joke.text)

# %%
df3 = pd.DataFrame(results_joke)
df3.drop(columns = ["type", "id"], inplace = True)

# %%
df3
# Out:
#                                                setup  \
# 0                     Why did the belt go to prison?
# 1  What was a more important invention than the f...
# 2           I was gonna tell you a joke about UDP...
# 3        What's the best thing about elevator jokes?
# 4             How can you tell a vampire has a cold?
# 5        Why can't you use "Beef stew"as a password?
# 6  I saw a nice stereo on Craigslist for $1. Sell...
# 7         What is a tornado's favorite game to play?
# 8                   Why did the programmer go broke?
# 9               Why didn't the skeleton go for prom?
#
#                       punchline
# 0   He held up a pair of pants!
# 1               The second one.
# 2  ...but you might not get it.
# 3  They work on so many levels.
# 4            They start coffin.
# 5  Because it's not stroganoff.
# 6      I couldn’t turn it down.
# 7                      Twister!
# 8      He used up all his cache
# 9        Because it had nobody.
