# %%
print("hello world")
# Out:
# hello world

# %%
print("Hello, Python1")
# Out:
# Hello, Python1

# %%
import sys
print(sys.version)
#sys, python'ın kendi modülüdür ve sistemle alakalı bilgi tutar.
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %%
frint("Hello, Python!")
#Error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 frint("Hello, Python!")
#
# NameError: name 'frint' is not defined
