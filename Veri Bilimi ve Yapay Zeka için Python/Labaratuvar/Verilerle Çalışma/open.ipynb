# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'open.ipynb']

# %%
with open("ornek.txt", "w", encoding = "utf-8") as f:
    f.write("Birinci satır\n")
    f.write("İkinci satır\n")
    f.write("Üçüncü satır\n")

# %%
with open("ornek.txt", "r", encoding = "utf-8") as f:
    icerik = f.read()

print(icerik)
# Out:
# Birinci satır
# İkinci satır
# Üçüncü satır
# Dördüncü satır (append ile eklendi)
# Beşinci satır da eklendi

# %%
with open("ornek.txt", "r", encoding = "utf-8") as f:
    for satir in f:
        print("Satır: ", satir.strip())
# Out:
# Satır:  Birinci satır
# Satır:  İkinci satır
# Satır:  Üçüncü satır

# %%
with open("ornek.txt", "a", encoding = "utf-8") as f: 
    f.write("Dördüncü satır (append ile eklendi)\n")
    f.write("Beşinci satır da eklendi\n")
